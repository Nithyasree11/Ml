# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import nsepy as ny

from datetime import date

# %%
A1 = ny.get_history(symbol='SBIN',
                   start=date(2015,1,1),
                   end=date(2015,1,10))
A1
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2015-01-01  313.67   6138488  1.925489e+14   58688             1877677
# 2015-01-02  316.80   9935094  3.147389e+14   79553             4221685
# 2015-01-05  313.84   9136716  2.867432e+14   88236             3845173
# ...

# %%
A2 = ny.get_history(symbol='SBIN',
                   start=date(2020,4,1),
                   end=date(2020,4,10))
A2
# Out:
#            Symbol Series  Prev Close    Open   High     Low    Last   Close  \
# Date
# 2020-04-01   SBIN     EQ      196.85  194.00  194.5  185.25  187.00  186.55
# 2020-04-03   SBIN     EQ      186.55  187.55  188.2  175.00  176.00  175.50
# 2020-04-07   SBIN     EQ      175.50  184.40  187.3  177.60  185.75  186.40
# 2020-04-08   SBIN     EQ      186.40  182.90  194.4  180.45  182.80  183.00
# 2020-04-09   SBIN     EQ      183.00  188.00  190.0  183.60  187.55  187.75
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2020-04-01  188.22  52954482  9.967150e+14  400004            15025872
# 2020-04-03  178.56  64455937  1.150915e+15  589657            22742948
# 2020-04-07  182.25  72133717  1.314668e+15  486914            15551736
# 2020-04-08  186.60  80436673  1.500987e+15  501541            12076385
# 2020-04-09  187.20  62417301  1.168453e+15  366071             9350138
#
#             %Deliverble
# Date
# 2020-04-01       0.2838
# ...
